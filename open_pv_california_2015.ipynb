# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
open_pv_california_2015 = "open_pv_california_2015.csv"

# Read the City and Ride Data
read_open_pv_california_2015_df = pd.read_csv(open_pv_california_2015)

new_name = read_open_pv_california_2015_df.rename(columns = {"size_kw":"system_size_kw","annual_PV_prod":"annual_PV_prod_kwh"})
# change size_kw to system_size_kw, annual_PV_prod_kwh

new_name.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   state date_installed incentive_prog_names type  system_size_kw appraised  \
# 0    CA        10/2/15                  NaN  uir            4.88       NaN
# 1    CA        12/1/15                  NaN  uir           19.60       NaN
# 2    CA         1/1/15                  NaN  uir           44.90       NaN
# 3    CA         1/1/15                  NaN  uir           44.90       NaN
# 4    CA        4/21/15                  NaN  uir           54.70       NaN
#
#    zipcode install_type installer  cost_per_watt  \
# 0    91340  Residential       NaN           4.05
# 1    90274  Residential       NaN           2.54
# 2    90022   Commercial       NaN           4.14
# 3    90706   Commercial       NaN           4.15
# ...

# %%
compacted_df = new_name[["state","date_installed","incentive_prog_names","system_size_kw","zipcode","install_type",
                                                "installer","cost_per_watt","cost","utility_clean","county","annual_PV_prod_kwh"]]

new = compacted_df.dropna()
new
# Out:
#       state date_installed                               incentive_prog_names  \
# 12       CA       10/21/15  California Public Utilities Commission (Non-CS...
# 13       CA        10/7/15  California Public Utilities Commission (Non-CS...
# 14       CA        9/25/15  California Public Utilities Commission (Non-CS...
# 15       CA       12/18/15  California Public Utilities Commission (Non-CS...
# 16       CA        12/9/15  California Public Utilities Commission (Non-CS...
# 17       CA       10/21/15  California Public Utilities Commission (Non-CS...
# 18       CA        10/5/15  California Public Utilities Commission (Non-CS...
# 21       CA       12/31/15  California Public Utilities Commission (Non-CS...
# 22       CA       12/28/15  California Public Utilities Commission (Non-CS...
# 23       CA       12/25/15  California Public Utilities Commission (Non-CS...
# 24       CA       12/25/15  California Public Utilities Commission (Non-CS...
# ...

# %%
new.to_csv("california_pv_2015_df.csv", encoding="utf-8", index=False)

# %%
# File to Load (Remember to change these)
climate_zip_code = "BuildingClimateZonesByZIPCode.csv"

# Read the data
climate_zip_code_df = pd.read_csv(climate_zip_code)

# Combine the data into a single dataset
combined_data_df = pd.merge(new, climate_zip_code_df, on="zipcode")

# Display the data table for preview
combined_data_df.head()
# Out:
#   state date_installed                               incentive_prog_names  \
# 0    CA       10/21/15  California Public Utilities Commission (Non-CS...
# 1    CA        9/23/15  California Public Utilities Commission (Non-CS...
# 2    CA        9/23/15  California Public Utilities Commission (Non-CS...
# 3    CA       10/29/15  California Public Utilities Commission (Non-CS...
# 4    CA       10/29/15  California Public Utilities Commission (Non-CS...
#
#    system_size_kw  zipcode install_type        installer  cost_per_watt  \
# 0          7.0672    93720  residential  Energy Concepts       3.162497
# 1          6.5604    93720  residential        SolarCity       1.704481
# 2          6.5604    93720  residential        SolarCity       1.704481
# 3          6.5604    93720  residential        SolarCity       5.681513
# 4          5.9775    93720  residential             Self       5.855291
#
#        cost                   utility_clean  county  annual_PV_prod_kwh  \
# ...

# %%
# Groupby commercial and residential

# %%
# Bin system size, and show visually

# Try and compare this to cost per watt, and annual PV prod kwh to find correlation, visually

# Use statistical test to test this correlation

# %%
# Map of climate zone to number of installations by county

# %%
# Heat map of installations by zip code

# %%
# Pie chart of installers

# %%
# Bar graph by incentive program
