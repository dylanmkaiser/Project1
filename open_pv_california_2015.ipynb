# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
open_pv_california_2015 = "open_pv_california_2015.csv"

# Read the City and Ride Data
read_open_pv_california_2015_df = pd.read_csv(open_pv_california_2015)

read_open_pv_california_2015_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   state date_installed incentive_prog_names type  size_kw appraised  zipcode  \
# 0    CA        10/2/15                  NaN  uir     4.88       NaN    91340
# 1    CA        12/1/15                  NaN  uir    19.60       NaN    90274
# 2    CA         1/1/15                  NaN  uir    44.90       NaN    90022
# 3    CA         1/1/15                  NaN  uir    44.90       NaN    90706
# 4    CA        4/21/15                  NaN  uir    54.70       NaN    92879
#
#   install_type installer  cost_per_watt  \
# 0  Residential       NaN           4.05
# 1  Residential       NaN           2.54
# 2   Commercial       NaN           4.14
# 3   Commercial       NaN           4.15
# 4   Commercial       NaN           4.34
#
# ...

# %%
compacted_df = read_open_pv_california_2015_df[["state","date_installed","incentive_prog_names","size_kw","zipcode","install_type",
                                                "installer","cost_per_watt","cost","utility_clean","county","annual_PV_prod"]]

compacted_df.dropna().head()

compacted_df.to_csv("california_pv_2015_df.csv", encoding="utf-8", index=False)
